# %%
print("16/12/2025")
print("Tuesday")
print("Internship class")
# Out:
# 16/12/2025
# Tuesday
# Internship class

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import requests

# %%
url = "https://api.agify.io?name=Pannamaneni Dyothi Sai Lalitha"
response = requests.get(url)
print(response.status_code)
print(response.json())
# Out:
# 200
# {'count': 192, 'name': 'Pannamaneni Dyothi Sai Lalitha', 'age': 66}
